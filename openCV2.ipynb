# %% [markdown]
# <a href="https://colab.research.google.com/github/alisha12548/AI/blob/main/openCV2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2

# %%
face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + "haarcascade_frontalface_default.xml")

# %%
cap = cv2.VideoCapture(0)

# %%
if not cap.isOpened():
    print("Error: Could not open webcam.")
    cap = None  # Set cap to None if it fails to open, instead of exiting
# Out:
# Error: Could not open webcam.

# %%
print("Press 'q' to quit")
# Out:
# Press 'q' to quit

# %%
if cap is not None:
    while True:
        ret, frame = cap.read()

        if not ret:
            print("Error: Failed to grab frame.")
            break

        gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)

        faces = face_cascade.detectMultiScale(
            gray,
            scaleFactor=1.1,
            minNeighbors=5,
            minSize=(30, 30),
            flags=cv2.CASCADE_SCALE_IMAGE
        )

        for (x, y, w, h) in faces:
            cv2.rectangle(frame, (x, y), (x+w, y+h), (255, 0, 0), 2)

        cv2.imshow('Face Detection', frame)

        if cv2.waitKey(1) & 0xFF == ord('q'):
            break

    cap.release()
    cv2.destroyAllWindows()
else:
    print("Webcam not available. Skipping live face detection.")
# Out:
# Webcam not available. Skipping live face detection.
